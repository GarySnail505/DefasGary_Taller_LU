# %% [markdown]
# # Taller Descomposición LU
# Gary Defas

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from src import (
    eliminacion_gaussiana,
    descomposicion_LU,
    resolver_LU,
    matriz_aumentada,
    separar_m_aumentada,
    gauss_jordan_inversa,
    calcular_matriz_vector,
    calcular_Ly_b_sustitucion_adelante,
    definiendo_Ux_y,
    sustitucion_atras_Ux_y
)

# %% [markdown]
# ## Ejercicio 1
# ![image.png](attachment:image.png)

# %%
A1 = [
    [1,3,4],
    [2,1,3],
    [4,2,1]
]
gauss_jordan_inversa(A1)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   3.   4.   1.   0.   0.]
#  [  0.  -5.  -5.  -2.   1.   0.]
#  [  0. -10. -15.  -4.   0.   1.]]
# [01-13 17:56:52][INFO]
# [[ 1.   0.   1.  -0.2  0.6  0. ]
#  [-0.   1.   1.   0.4 -0.2 -0. ]
#  [ 0.   0.  -5.   0.  -2.   1. ]]
# [01-13 17:56:52][INFO]
# [[ 1.   0.   0.  -0.2  0.2  0.2]
#  [ 0.   1.   0.   0.4 -0.6  0.2]
#  [-0.  -0.   1.  -0.   0.4 -0.2]]
# array([[-0.2,  0.2,  0.2],
#        [ 0.4, -0.6,  0.2],
#        [-0. ,  0.4, -0.2]])

# %%
A2 = [
    [1,2,3],
    [0,1,4],
    [5,6,0]
]
gauss_jordan_inversa(A2)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   2.   3.   1.   0.   0.]
#  [  0.   1.   4.   0.   1.   0.]
#  [  0.  -4. -15.  -5.   0.   1.]]
# [01-13 17:56:52][INFO]
# [[ 1.  0. -5.  1. -2.  0.]
#  [ 0.  1.  4.  0.  1.  0.]
#  [ 0.  0.  1. -5.  4.  1.]]
# [01-13 17:56:52][INFO]
# [[  1.   0.   0. -24.  18.   5.]
#  [  0.   1.   0.  20. -15.  -4.]
#  [  0.   0.   1.  -5.   4.   1.]]
# array([[-24.,  18.,   5.],
#        [ 20., -15.,  -4.],
#        [ -5.,   4.,   1.]])

# %%
A3 = [
    [4,2,1],
    [2,1,3],
    [1,3,4]
]
gauss_jordan_inversa(A3)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   3.   4.   0.   0.   1.]
#  [  0.  -5.  -5.   0.   1.  -2.]
#  [  0. -10. -15.   1.   0.  -4.]]
# [01-13 17:56:52][INFO]
# [[ 1.   0.   1.   0.   0.6 -0.2]
#  [-0.   1.   1.  -0.  -0.2  0.4]
#  [ 0.   0.  -5.   1.  -2.   0. ]]
# [01-13 17:56:52][INFO]
# [[ 1.   0.   0.   0.2  0.2 -0.2]
#  [ 0.   1.   0.   0.2 -0.6  0.4]
#  [-0.  -0.   1.  -0.2  0.4 -0. ]]
# array([[ 0.2,  0.2, -0.2],
#        [ 0.2, -0.6,  0.4],
#        [-0.2,  0.4, -0. ]])

# %%
A4 = [
    [2,4,6,1],
    [4,7,5,-6],
    [2,5,18,10],
    [6,12,38,16]
]
gauss_jordan_inversa(A4)
# Out:
# [01-13 17:56:52][INFO]
# [[ 1.   2.   3.   0.5  0.5  0.   0.   0. ]
#  [ 0.  -1.  -7.  -8.  -2.   1.   0.   0. ]
#  [ 0.   1.  12.   9.  -1.   0.   1.   0. ]
#  [ 0.   0.  20.  13.  -3.   0.   0.   1. ]]
# [01-13 17:56:52][INFO]
# [[  1.    0.  -11.  -15.5  -3.5   2.    0.    0. ]
#  [ -0.    1.    7.    8.    2.   -1.   -0.   -0. ]
#  [  0.    0.    5.    1.   -3.    1.    1.    0. ]
#  [  0.    0.   20.   13.   -3.    0.    0.    1. ]]
# [01-13 17:56:52][INFO]
# [[  1.    0.    0.  -13.3 -10.1   4.2   2.2   0. ]
#  [ -0.    1.    0.    6.6   6.2  -2.4  -1.4  -0. ]
#  [  0.    0.    1.    0.2  -0.6   0.2   0.2   0. ]
#  [  0.    0.    0.    9.    9.   -4.   -4.    1. ]]
# [01-13 17:56:52][INFO]
# [[ 1.          0.          0.          0.          3.2        -1.71111111
#   -3.71111111  1.47777778]
#  [-0.          1.          0.          0.         -0.4         0.53333333
#    1.53333333 -0.73333333]
#  [ 0.          0.          1.          0.         -0.8         0.28888889
# ...

# %% [markdown]
# ## Ejercicio 2
#
# Calcule la descomposición LU para estas matrices y encuentre la solución para estos vectores de valores independientes b
#
# ![image.png](attachment:image.png)

# %%
b1 = [1,2,4]
b2 = [3,-5,2]
b3 = [7,8,-1]
b4 = [1,2,4,5]
b5 = [3,-5,2,6]
b6 = [7,8,-1,0]

# %% [markdown]
# ### Calculando $A_1*b_1$

# %%
## A1 * b1

calcular_LU = descomposicion_LU(A1)

L, U = calcular_LU  

resolver_LU(L, U, b1)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   3.   4.]
#  [  0.  -5.  -5.]
#  [  0. -10. -15.]]
# [01-13 17:56:52][INFO]
# [[ 1.  3.  4.]
#  [ 0. -5. -5.]
#  [ 0.  0. -5.]]
# [01-13 17:56:52][INFO]
# [[ 1.  3.  4.]
#  [ 0. -5. -5.]
#  [ 0.  0. -5.]]
# [01-13 17:56:52][INFO] Sustitución hacia adelante
# [01-13 17:56:52][INFO] y =
# [[1.]
#  [0.]
#  [0.]]
# [01-13 17:56:52][INFO] Sustitución hacia atrás
# [01-13 17:56:52][INFO] i = 1
# [01-13 17:56:52][INFO] suma = [0.]
# [01-13 17:56:52][INFO] U[i, i] = -5.0
# [01-13 17:56:52][INFO] y[i] = [0.]
# [01-13 17:56:52][INFO] i = 0
# [01-13 17:56:52][INFO] suma = [0.]
# [01-13 17:56:52][INFO] U[i, i] = 1.0
# [01-13 17:56:52][INFO] y[i] = [1.]
# array([[ 1.],
#        [-0.],
#        [-0.]])

# %%
y = calcular_Ly_b_sustitucion_adelante(L, b1)
print(y)

x = sustitucion_atras_Ux_y(U, y)
print(x)
# Out:
# [[1.]
#  [0.]
#  [0.]]
# [[ 1.]
#  [-0.]
#  [-0.]]

# %%
A_1 = matriz_aumentada(A1, b1)
eliminacion_gaussiana(A_1)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   3.   4.   1.]
#  [  0.  -5.  -5.   0.]
#  [  0. -10. -15.   0.]]
# [01-13 17:56:52][INFO]
# [[ 1.  3.  4.  1.]
#  [ 0. -5. -5.  0.]
#  [ 0.  0. -5.  0.]]
# array([ 1., -0., -0.])

# %% [markdown]
# ### Calculando $A_2*b_2$

# %%
###  A2 * b2
calcular_LU = descomposicion_LU(A2)
L, U = calcular_LU
resolver_LU(L, U, b2)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   2.   3.]
#  [  0.   1.   4.]
#  [  0.  -4. -15.]]
# [01-13 17:56:52][INFO]
# [[1. 2. 3.]
#  [0. 1. 4.]
#  [0. 0. 1.]]
# [01-13 17:56:52][INFO]
# [[1. 2. 3.]
#  [0. 1. 4.]
#  [0. 0. 1.]]
# [01-13 17:56:52][INFO] Sustitución hacia adelante
# [01-13 17:56:52][INFO] y =
# [[  3.]
#  [ -5.]
#  [-33.]]
# [01-13 17:56:52][INFO] Sustitución hacia atrás
# [01-13 17:56:52][INFO] i = 1
# [01-13 17:56:52][INFO] suma = [-132.]
# [01-13 17:56:52][INFO] U[i, i] = 1.0
# [01-13 17:56:52][INFO] y[i] = [-5.]
# [01-13 17:56:52][INFO] i = 0
# [01-13 17:56:52][INFO] suma = [155.]
# [01-13 17:56:52][INFO] U[i, i] = 1.0
# [01-13 17:56:52][INFO] y[i] = [3.]
# array([[-152.],
#        [ 127.],
#        [ -33.]])

# %%
A_2 = matriz_aumentada(A2, b2)
eliminacion_gaussiana(A_2)
# Out:
# [01-13 17:56:52][INFO]
# [[  1.   2.   3.   3.]
#  [  0.   1.   4.  -5.]
#  [  0.  -4. -15. -13.]]
# [01-13 17:56:52][INFO]
# [[  1.   2.   3.   3.]
#  [  0.   1.   4.  -5.]
#  [  0.   0.   1. -33.]]
# array([-152.,  127.,  -33.])

# %%
y = calcular_Ly_b_sustitucion_adelante(L, b2)
print(y)

x = sustitucion_atras_Ux_y(U, y)
print(x)
# Out:
# [[  3.]
#  [ -5.]
#  [-33.]]
# [[-152.]
#  [ 127.]
#  [ -33.]]

# %% [markdown]
# ### Calculando $A_3*b_3$

# %%
### A3 * b3
calcular_LU = descomposicion_LU(A3)
L, U = calcular_LU
resolver_LU(L, U, b3)
# Out:
# [01-13 17:56:52][INFO]
# [[4.   2.   1.  ]
#  [0.   0.   2.5 ]
#  [0.   2.5  3.75]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 2
#       1 ### A3 * b3
# ----> 2 calcular_LU = descomposicion_LU(A3)
#       3 L, U = calcular_LU
#       4 resolver_LU(L, U, b3)
#
# File c:\Users\P3E009-E\DefasGary_Taller_LU\src\linear_syst_methods.py:58, in descomposicion_LU(A)
#      54 for i in range(0, n):  # loop por columna
#      55
#      56     # --- deterimnar pivote
#      57     if A[i, i] == 0:
# ---> 58         raise ValueError("No existe solución única.")
#      60     # --- Eliminación: loop por fila
#      61     L[i, i] = 1
#
# ValueError: No existe solución única.

# %%
A_3 = matriz_aumentada(A3, b3)
eliminacion_gaussiana(A_3)
# Out:
# [01-13 17:28:23][INFO]
# [[  1.   3.   4.  -1.]
#  [  0.  -5.  -5.  10.]
#  [  0. -10. -15.  11.]]
# [01-13 17:28:23][INFO]
# [[ 1.  3.  4. -1.]
#  [ 0. -5. -5. 10.]
#  [ 0.  0. -5. -9.]]
# array([ 3.2, -3.8,  1.8])

# %% [markdown]
# ### Calculando $A_4*b_4$

# %%
#### A4 * b4
calcular_LU = descomposicion_LU(A4)
L, U = calcular_LU
resolver_LU(L, U, b4)
# Out:
# [01-13 17:57:32][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  1. 12.  9.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:57:32][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:57:32][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:57:32][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:57:32][INFO] Sustitución hacia adelante
# [01-13 17:57:32][INFO] y =
# [[  1.]
#  [  0.]
#  [  3.]
#  [-10.]]
# [01-13 17:57:32][INFO] Sustitución hacia atrás
# [01-13 17:57:32][INFO] i = 2
# [01-13 17:57:32][INFO] suma = [-1.11111111]
# [01-13 17:57:32][INFO] U[i, i] = 5.0
# [01-13 17:57:32][INFO] y[i] = [3.]
# [01-13 17:57:32][INFO] i = 1
# [01-13 17:57:32][INFO] suma = [3.13333333]
# [01-13 17:57:32][INFO] U[i, i] = -1.0
# [01-13 17:57:32][INFO] y[i] = [0.]
# [01-13 17:57:32][INFO] i = 0
# [01-13 17:57:32][INFO] suma = [16.35555556]
# ...

# %%
y = calcular_Ly_b_sustitucion_adelante(L, b4)
print(y)

x = sustitucion_atras_Ux_y(U, y)
print(x)
# Out:
# [[  1.]
#  [  0.]
#  [  3.]
#  [-10.]]
# [[-7.67777778]
#  [ 3.13333333]
#  [ 0.82222222]
#  [-1.11111111]]

# %%
A_4 = matriz_aumentada(A4, b4)
eliminacion_gaussiana(A_4)
# Out:
# [01-13 17:13:23][INFO]
# [[ 2.  4.  6.  1.  1.]
#  [ 0. -1. -7. -8.  0.]
#  [ 0.  1. 12.  9.  3.]
#  [ 0.  0. 20. 13.  2.]]
# [01-13 17:13:23][INFO]
# [[ 2.  4.  6.  1.  1.]
#  [ 0. -1. -7. -8.  0.]
#  [ 0.  0.  5.  1.  3.]
#  [ 0.  0. 20. 13.  2.]]
# [01-13 17:13:23][INFO]
# [[  2.   4.   6.   1.   1.]
#  [  0.  -1.  -7.  -8.   0.]
#  [  0.   0.   5.   1.   3.]
#  [  0.   0.   0.   9. -10.]]
# array([-7.67777778,  3.13333333,  0.82222222, -1.11111111])

# %% [markdown]
# ### Calculando $A_4*b_5$

# %%
calcular_LU = descomposicion_LU(A4)
L, U = calcular_LU
resolver_LU(L, U, b5)
# Out:
# [01-13 17:15:23][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  1. 12.  9.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:15:23][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:15:23][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:15:23][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:15:23][INFO] Sustitución hacia adelante
# [01-13 17:15:23][INFO] y =
# [[  3.]
#  [-11.]
#  [-12.]
#  [ 45.]]
# [01-13 17:15:23][INFO] Sustitución hacia atrás
# [01-13 17:15:23][INFO] i = 2
# [01-13 17:15:23][INFO] suma = [5.]
# [01-13 17:15:23][INFO] U[i, i] = 5.0
# [01-13 17:15:23][INFO] y[i] = [-12.]
# [01-13 17:15:23][INFO] i = 1
# [01-13 17:15:23][INFO] suma = [-16.2]
# [01-13 17:15:23][INFO] U[i, i] = -1.0
# [01-13 17:15:23][INFO] y[i] = [-11.]
# [01-13 17:15:23][INFO] i = 0
# [01-13 17:15:23][INFO] suma = [-36.2]
# ...

# %%
y = calcular_Ly_b_sustitucion_adelante(L, b5)
print(y)

x = sustitucion_atras_Ux_y(U, y)
print(x)

# %%
A_4_5 = matriz_aumentada(A4, b5)
eliminacion_gaussiana(A_4_5)
# Out:
# [01-13 17:16:04][INFO]
# [[  2.   4.   6.   1.   3.]
#  [  0.  -1.  -7.  -8. -11.]
#  [  0.   1.  12.   9.  -1.]
#  [  0.   0.  20.  13.  -3.]]
# [01-13 17:16:04][INFO]
# [[  2.   4.   6.   1.   3.]
#  [  0.  -1.  -7.  -8. -11.]
#  [  0.   0.   5.   1. -12.]
#  [  0.   0.  20.  13.  -3.]]
# [01-13 17:16:04][INFO]
# [[  2.   4.   6.   1.   3.]
#  [  0.  -1.  -7.  -8. -11.]
#  [  0.   0.   5.   1. -12.]
#  [  0.   0.   0.   9.  45.]]
# array([19.6, -5.2, -3.4,  5. ])

# %% [markdown]
# ### Calculando $A_4*b_6$

# %%
calcular_LU = descomposicion_LU(A4)
L, U = calcular_LU
resolver_LU(L, U, b6)
# Out:
# [01-13 17:18:52][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  1. 12.  9.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:18:52][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0. 20. 13.]]
# [01-13 17:18:52][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:18:52][INFO]
# [[ 2.  4.  6.  1.]
#  [ 0. -1. -7. -8.]
#  [ 0.  0.  5.  1.]
#  [ 0.  0.  0.  9.]]
# [01-13 17:18:52][INFO] Sustitución hacia adelante
# [01-13 17:18:52][INFO] y =
# [[  7.]
#  [ -6.]
#  [-14.]
#  [ 35.]]
# [01-13 17:18:52][INFO] Sustitución hacia atrás
# [01-13 17:18:52][INFO] i = 2
# [01-13 17:18:52][INFO] suma = [3.88888889]
# [01-13 17:18:52][INFO] U[i, i] = 5.0
# [01-13 17:18:52][INFO] y[i] = [-14.]
# [01-13 17:18:52][INFO] i = 1
# [01-13 17:18:52][INFO] suma = [-6.06666667]
# [01-13 17:18:52][INFO] U[i, i] = -1.0
# [01-13 17:18:52][INFO] y[i] = [-6.]
# [01-13 17:18:52][INFO] i = 0
# [01-13 17:18:52][INFO] suma = [-17.84444444]
# ...

# %%
y = calcular_Ly_b_sustitucion_adelante(L, b6)
print(y)

x = sustitucion_atras_Ux_y(U, y)
print(x)

# %%
a_4_6 = matriz_aumentada(A4, b6)
eliminacion_gaussiana(a_4_6)
# Out:
# [01-13 17:18:41][INFO]
# [[  2.   4.   6.   1.   7.]
#  [  0.  -1.  -7.  -8.  -6.]
#  [  0.   1.  12.   9.  -8.]
#  [  0.   0.  20.  13. -21.]]
# [01-13 17:18:41][INFO]
# [[  2.   4.   6.   1.   7.]
#  [  0.  -1.  -7.  -8.  -6.]
#  [  0.   0.   5.   1. -14.]
#  [  0.   0.  20.  13. -21.]]
# [01-13 17:18:41][INFO]
# [[  2.   4.   6.   1.   7.]
#  [  0.  -1.  -7.  -8.  -6.]
#  [  0.   0.   5.   1. -14.]
#  [  0.   0.   0.   9.  35.]]
# array([12.42222222, -0.06666667, -3.57777778,  3.88888889])
